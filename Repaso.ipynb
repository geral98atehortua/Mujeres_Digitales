# %% [markdown]
# <a href="https://colab.research.google.com/github/geral98atehortua/Mujeres_Digitales/blob/main/Repaso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
entero =1
flotante =1.0
cadena ="1"
cadena2='1'
lista=[1,2]
lista2=[3,4]
diccionario={1:2}

print('tipo de variables')
print(entero)
print(flotante)
print(cadena)
print(lista)
print(diccionario)


print('operaciones')
print(entero+flotante)

print(lista[0])

#ciclos for y while
print('ciclo for')

for i in lista:
    print(i)
    
for i in range(0,5,1):
    print(i)
  

for i in range(len(lista)):  #len = longitud de la lista
    print((lista[i]+lista2[i])/2)
    
    

print(range(5))   
print(range(0,5))
print(range(0,5,1)) #explica los saltos
        
lista3=[0,1,2,3,4]

for i in  range(1,len(lista3)-1,2): #escoges afuera cuales no ir y de cuanto en cuanto como el "-1" el ultimo y el "2" de dos en dos.
    print(lista3[i])
     
print(len(lista3))#cantidad de elementos de un arreglo


#otro ejemplo

a=['a','b']     #imprime cada elemento a lo largo de "a"
for i in a:
 print(i)


#imprime el primer elemento de cada lista y asi sucesivamente con el segundo.

a=['a','b']       
lista=[1,2]
lista2=[3,4]      
        
for i in range(len(a)):
    print(a[i],lista[i],lista2[i])
    
#funcion enumerar: muestra indice y elemento


for indice, elem in enumerate(a):
   print(indice,elem)

b =['cero','uno','dos','tres']
for indice,elem in enumerate(b):
   print(indice,elem)
 
    
#imprimir más manual y luego con for todo a la vez
    
b =['cero','uno','dos','tres']

print(b[0])
print(b[1])
print(b[2])
print(b[3])

for i in range(len(b)):
    print(i,b[i])


#enumerate en lista de listss

c=[['a','b'],['c','d']]

print(c[0])
print(c[1])

for i in range(len(c)):
    print(i,c[i])

for i,e in enumerate(c):
    print(i,e)

print(c[0][0])
print(c[i][0])

print(c[i][0])
